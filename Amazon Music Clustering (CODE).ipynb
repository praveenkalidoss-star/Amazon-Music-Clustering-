# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/single_genre_artists.csv")
df
# Out:
#                      id_songs          name_song  popularity_songs  \
# 0      0IA0Hju8CAgYfV1hwhidBH            La Java                 0
# 1      1b8HZQCqcqwbzlA1jRTp6E           En Douce                 0
# 2      5d5gQxHwYovxR5pqETOIAa      J'en Ai Marre                 0
# 3      1EO65UEEPfy7CR0NK2sDxy   Ils n'ont pas ca                 0
# 4      6a58gXSgqbIsXUhVZ6ZJqe          La belote                 0
# ...                       ...                ...               ...
# 95832  44r4zta6P9flkhKaVnbsvG             Freaks                70
# 95833  0MmaEacabpK8Yp3Mdeo5uY                下雨天                50
# 95834  1dKxf4Ht2SsKLyXfSDJAgy   The Cutest Puppy                67
# 95835  0SjsIzJkZfDU7wlcdklEFR  John Brown's Song                66
# 95836  5rgu12WBIHQtvej2MdHSH0                云与海                50
#
#        duration_ms  explicit              id_artists release_date  \
# 0           161427         0  4AxgXfD7ISvJSTObqm4aIE         1922
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95837 entries, 0 to 95836
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_songs            95837 non-null  object
#  1   name_song           95837 non-null  object
#  2   popularity_songs    95837 non-null  int64
#  3   duration_ms         95837 non-null  int64
#  4   explicit            95837 non-null  int64
#  5   id_artists          95837 non-null  object
#  6   release_date        95837 non-null  object
#  7   danceability        95837 non-null  float64
#  8   energy              95837 non-null  float64
#  9   key                 95837 non-null  int64
#  10  loudness            95837 non-null  float64
#  11  mode                95837 non-null  int64
#  12  speechiness         95837 non-null  float64
#  13  acousticness        95837 non-null  float64
#  14  instrumentalness    95837 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['id_songs', 'name_song', 'popularity_songs', 'duration_ms', 'explicit',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'followers', 'genres',
#        'name_artists', 'popularity_artists'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                  id_songs         name_song  popularity_songs  duration_ms  \
# 0  0IA0Hju8CAgYfV1hwhidBH           La Java                 0       161427
# 1  1b8HZQCqcqwbzlA1jRTp6E          En Douce                 0       223440
# 2  5d5gQxHwYovxR5pqETOIAa     J'en Ai Marre                 0       208267
# 3  1EO65UEEPfy7CR0NK2sDxy  Ils n'ont pas ca                 0       161933
# 4  6a58gXSgqbIsXUhVZ6ZJqe         La belote                 0       167973
# 5  6sVxCBvLSd9PZA7prJn53O   Oh mademoiselle                 0       158693
# 6  3S9RAJj909UR6oOfaGxwad    Il m'a vue nue                 0       196507
# 7  3vuypSGFgGT7JKJiWPJURp      Mon Bus'ness                 0       172840
# 8  50gOBrK00pGazhLXGMEqwc    Ça c'est Paris                 0       172987
# 9  3k4N13FLmeIcETs5zwxnvd           Le Fado                 0       154733
#
#    explicit              id_artists release_date  danceability  energy  key  \
# ...

# %%
df['followers'] = df['followers'].astype(int)

# %%
# import pandas as pd

# def convert_to_year(x):
#     # If full date (YYYY-MM-DD), split and take year
#     if '-' in str(x):
#         return int(str(x).split('-')[0])
#     # If only year (e.g., '1924')
#         # convert to integer
#     try:
#         return int(x)
#     except:
#         return None

# %%
def convert_to_year(x):
    x = str(x)
    if "-" in x:
        return int(x.split("-")[0])
    try:
        return int(x)
    except:
        return None

# %%
df
# Out:
#                      id_songs          name_song  popularity_songs  \
# 0      0IA0Hju8CAgYfV1hwhidBH            La Java                 0
# 1      1b8HZQCqcqwbzlA1jRTp6E           En Douce                 0
# 2      5d5gQxHwYovxR5pqETOIAa      J'en Ai Marre                 0
# 3      1EO65UEEPfy7CR0NK2sDxy   Ils n'ont pas ca                 0
# 4      6a58gXSgqbIsXUhVZ6ZJqe          La belote                 0
# ...                       ...                ...               ...
# 95832  44r4zta6P9flkhKaVnbsvG             Freaks                70
# 95833  0MmaEacabpK8Yp3Mdeo5uY                下雨天                50
# 95834  1dKxf4Ht2SsKLyXfSDJAgy   The Cutest Puppy                67
# 95835  0SjsIzJkZfDU7wlcdklEFR  John Brown's Song                66
# 95836  5rgu12WBIHQtvej2MdHSH0                云与海                50
#
#        duration_ms  explicit              id_artists release_date  \
# 0           161427         0  4AxgXfD7ISvJSTObqm4aIE         1922
# ...

# %%
df['release_year'] = df['release_date'].apply(convert_to_year)
df['release_year'] = df['release_year'].astype('Int64')  # keep clean type

# %%
df
# Out:
#                      id_songs          name_song  popularity_songs  \
# 0      0IA0Hju8CAgYfV1hwhidBH            La Java                 0
# 1      1b8HZQCqcqwbzlA1jRTp6E           En Douce                 0
# 2      5d5gQxHwYovxR5pqETOIAa      J'en Ai Marre                 0
# 3      1EO65UEEPfy7CR0NK2sDxy   Ils n'ont pas ca                 0
# 4      6a58gXSgqbIsXUhVZ6ZJqe          La belote                 0
# ...                       ...                ...               ...
# 95832  44r4zta6P9flkhKaVnbsvG             Freaks                70
# 95833  0MmaEacabpK8Yp3Mdeo5uY                下雨天                50
# 95834  1dKxf4Ht2SsKLyXfSDJAgy   The Cutest Puppy                67
# 95835  0SjsIzJkZfDU7wlcdklEFR  John Brown's Song                66
# 95836  5rgu12WBIHQtvej2MdHSH0                云与海                50
#
#        duration_ms  explicit              id_artists release_date  \
# 0           161427         0  4AxgXfD7ISvJSTObqm4aIE         1922
# ...

# %%
df['release_date'].unique()
# Out:
# array(['1922', '1924', '1925', ..., '1968-12-12', '1996-02-16',
#        '2009-11-28'], dtype=object)

# %%
df.drop(columns=['release_date'], inplace=True)

# %%
df
# Out:
#                      id_songs          name_song  popularity_songs  \
# 0      0IA0Hju8CAgYfV1hwhidBH            La Java                 0
# 1      1b8HZQCqcqwbzlA1jRTp6E           En Douce                 0
# 2      5d5gQxHwYovxR5pqETOIAa      J'en Ai Marre                 0
# 3      1EO65UEEPfy7CR0NK2sDxy   Ils n'ont pas ca                 0
# 4      6a58gXSgqbIsXUhVZ6ZJqe          La belote                 0
# ...                       ...                ...               ...
# 95832  44r4zta6P9flkhKaVnbsvG             Freaks                70
# 95833  0MmaEacabpK8Yp3Mdeo5uY                下雨天                50
# 95834  1dKxf4Ht2SsKLyXfSDJAgy   The Cutest Puppy                67
# 95835  0SjsIzJkZfDU7wlcdklEFR  John Brown's Song                66
# 95836  5rgu12WBIHQtvej2MdHSH0                云与海                50
#
#        duration_ms  explicit              id_artists  danceability  energy  \
# 0           161427         0  4AxgXfD7ISvJSTObqm4aIE         0.563  0.1840
# ...

# %%
df.shape
# Out:
# (95837, 23)

# %%
df.describe().T
# Out:
#                       count           mean            std      min       25%  \
# popularity_songs    95837.0      26.066394      16.254133      0.0      13.0
# duration_ms         95837.0  208732.031835   117752.55595   6373.0  157333.0
# explicit            95837.0       0.029644       0.169604      0.0       0.0
# danceability        95837.0       0.586853       0.155422      0.0     0.488
# energy              95837.0       0.541083       0.236304  0.00002     0.365
# key                 95837.0       5.196782       3.534923      0.0       2.0
# loudness            95837.0     -10.157862       4.748798  -50.174   -12.723
# mode                95837.0       0.648069       0.477575      0.0       0.0
# speechiness         95837.0       0.168832       0.275417      0.0    0.0341
# acousticness        95837.0       0.458989       0.330416      0.0     0.133
# instrumentalness    95837.0       0.082145        0.23244      0.0       0.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id_songs              0
# name_song             0
# popularity_songs      0
# duration_ms           0
# explicit              0
# id_artists            0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# acousticness          0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# time_signature        0
# followers             0
# genres                0
# name_artists          0
# popularity_artists    0
# release_year          0
# dtype: int64

# %%
# df = df.drop(columns=['id_songs', 'name_song', 'id_artists'])

# %%
df = df.drop(columns=[
    'id_songs', 'name_song', 'id_artists',
    'name_artists', 'genres',
    'release_year', 'followers', 'popularity_artists'
])

# %%
df
# Out:
#        popularity_songs  duration_ms  explicit  danceability  energy  key  \
# 0                     0       161427         0         0.563  0.1840    4
# 1                     0       223440         0         0.427  0.1800   10
# 2                     0       208267         0         0.511  0.2060    0
# 3                     0       161933         0         0.676  0.4670    9
# 4                     0       167973         0         0.650  0.2980    9
# ...                 ...          ...       ...           ...     ...  ...
# 95832                70       174800         0         0.674  0.5680    1
# 95833                50       265846         0         0.528  0.6730    4
# 95834                67        82500         0         0.609  0.0172    8
# 95835                66       185250         0         0.562  0.0331    1
# 95836                50       258267         0         0.560  0.5180    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of key numerical features
features = [
    'danceability','energy','loudness','speechiness','acousticness',
    'instrumentalness','liveness','valence','tempo','duration_ms'
]

# Plot distributions
plt.figure(figsize=(15,12))

for i, col in enumerate(features, 1):
    plt.subplot(4, 3, i)
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Fit and transform only the selected features
X_scaled = scaler.fit_transform(df[features])

# Convert back to DataFrame for readability
scaled_df = pd.DataFrame(X_scaled, columns=features)

scaled_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.153476 -1.511128 -0.757909    -0.427109      1.616187
# 1     -1.028518 -1.528056 -1.098629    -0.369741      1.604081
# 2     -0.488051 -1.418027 -1.127899    -0.398062      1.622240
# 3      0.573581 -0.313510 -0.470677    -0.013914      1.610134
# 4      0.406294 -1.028695 -0.768227    -0.111948      1.610134
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.353338  0.538584  0.321287  0.515005    -0.401735
# 1         -0.353405 -0.521537 -0.577455 -1.294487     0.124906
# 2         -0.353405  1.039046 -0.375943 -1.560003    -0.003949
# 3         -0.353405 -0.031836  0.611464  0.405268    -0.397437
# 4         -0.353405  0.796887  1.087031 -1.377593    -0.346143

# %%
plt.figure(figsize=(15,12))

for i, col in enumerate(scaled_df.columns, 1):
    plt.subplot(4, 3, i)
    sns.histplot(scaled_df[col], kde=True, bins=30, color='green')
    plt.title(col + " (scaled)")

plt.tight_layout()
plt.show()

# %%
df[features].head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.563   0.184   -13.757       0.0512         0.993
# 1         0.427   0.180   -15.375       0.0670         0.989
# 2         0.511   0.206   -15.514       0.0592         0.995
# 3         0.676   0.467   -12.393       0.1650         0.991
# 4         0.650   0.298   -13.806       0.1380         0.991
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000016     0.325    0.654  133.088       161427
# 1          0.000000     0.128    0.431   78.459       223440
# 2          0.000000     0.418    0.481   70.443       208267
# 3          0.000000     0.219    0.726  129.775       161933
# 4          0.000000     0.373    0.844   75.950       167973

# %%
scaled_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.153476 -1.511128 -0.757909    -0.427109      1.616187
# 1     -1.028518 -1.528056 -1.098629    -0.369741      1.604081
# 2     -0.488051 -1.418027 -1.127899    -0.398062      1.622240
# 3      0.573581 -0.313510 -0.470677    -0.013914      1.610134
# 4      0.406294 -1.028695 -0.768227    -0.111948      1.610134
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.353338  0.538584  0.321287  0.515005    -0.401735
# 1         -0.353405 -0.521537 -0.577455 -1.294487     0.124906
# 2         -0.353405  1.039046 -0.375943 -1.560003    -0.003949
# 3         -0.353405 -0.031836  0.611464  0.405268    -0.397437
# 4         -0.353405  0.796887  1.087031 -1.377593    -0.346143

# %%
scaled_df.mean(), scaled_df.std()
# Out:
# (danceability        2.746173e-16
#  energy              5.456759e-17
#  loudness            4.033257e-17
#  speechiness        -4.982259e-17
#  acousticness        2.277604e-16
#  instrumentalness   -4.033257e-17
#  liveness           -3.796007e-17
#  valence             3.914632e-17
#  tempo              -2.075941e-16
#  duration_ms        -5.219509e-17
#  dtype: float64,
#  danceability        1.000005
#  energy              1.000005
#  loudness            1.000005
#  speechiness         1.000005
#  acousticness        1.000005
#  instrumentalness    1.000005
#  liveness            1.000005
#  valence             1.000005
#  tempo               1.000005
#  duration_ms         1.000005
#  dtype: float64)

# %%
# Step 2 - Feature Selection

selected_features = [
    'danceability',
    'energy',
    'loudness',
    'speechiness',
    'acousticness',
    'instrumentalness',
    'liveness',
    'valence',
    'tempo',
    'duration_ms'
]

# Create a new DataFrame with only these features
X = df[selected_features]

# Display first 5 rows
X.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.563   0.184   -13.757       0.0512         0.993
# 1         0.427   0.180   -15.375       0.0670         0.989
# 2         0.511   0.206   -15.514       0.0592         0.995
# 3         0.676   0.467   -12.393       0.1650         0.991
# 4         0.650   0.298   -13.806       0.1380         0.991
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000016     0.325    0.654  133.088       161427
# 1          0.000000     0.128    0.431   78.459       223440
# 2          0.000000     0.418    0.481   70.443       208267
# 3          0.000000     0.219    0.726  129.775       161933
# 4          0.000000     0.373    0.844   75.950       167973

# %%
# danceability + energy + tempo + loudness → PC1
# acousticness + valence + instrumentalness → PC2

# %%
from sklearn.decomposition import PCA
import pandas as pd

# PCA with 2 components for visualization
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

# Convert to DataFrame
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

# Display sample
pca_df.head()
# Out:
#         PC1       PC2
# 0 -1.676304  0.291571
# 1 -2.639968 -0.472803
# 2 -2.537328  0.474464
# 3 -0.677418  0.709757
# 4 -1.480657  1.426716

# %%
pca.explained_variance_ratio_, pca.explained_variance_ratio_.sum()
# Out:
# (array([0.27079553, 0.18821441]), np.float64(0.459009939910359))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], s=5, alpha=0.5)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Song Data")
plt.show()

# %%
pca.explained_variance_ratio_.sum()
# Out:
# np.float64(0.459009939910359)

# %%
df
# Out:
#        popularity_songs  duration_ms  explicit  danceability  energy  key  \
# 0                     0       161427         0         0.563  0.1840    4
# 1                     0       223440         0         0.427  0.1800   10
# 2                     0       208267         0         0.511  0.2060    0
# 3                     0       161933         0         0.676  0.4670    9
# 4                     0       167973         0         0.650  0.2980    9
# ...                 ...          ...       ...           ...     ...  ...
# 95832                70       174800         0         0.674  0.5680    1
# 95833                50       265846         0         0.528  0.6730    4
# 95834                67        82500         0         0.609  0.0172    8
# 95835                66       185250         0         0.562  0.0331    1
# 95836                50       258267         0         0.560  0.5180    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import numpy as np

inertia = []
sil_scores = []
K_range = range(2, 11)

# --- Downsample for silhouette score ---
sample_idx = np.random.choice(len(X_scaled), size=10000, replace=False)
X_sample = X_scaled[sample_idx]

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_scaled)
    inertia.append(kmeans.inertia_)

    # Compute silhouette only on sample
    sample_labels = kmeans.predict(X_sample)
    sil_scores.append(silhouette_score(X_sample, sample_labels))

# Plot Elbow
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(K_range, inertia, 'o-', color='blue')
plt.title('Elbow Method (SSE vs K)')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia / SSE')

plt.subplot(1,2,2)
plt.plot(K_range, sil_scores, 'o-', color='orange')
plt.title('Silhouette Score vs K')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')

plt.tight_layout()
plt.show()

# %%
best_k = 4  # example, choose based on your graph

# %%
best_k = 3

kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
df['cluster'] = kmeans.fit_predict(X_scaled)

df['cluster'].value_counts()
# Out:
# cluster
# 2    52508
# 1    30815
# 0    12514
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], c=df['cluster'], cmap='tab10', s=5)
plt.title("K-Means Clustering (k=3) on PCA Visualization")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.colorbar(label='Cluster')
plt.show()

# %%
cluster_profiles = df.groupby('cluster')[selected_features].mean()
cluster_profiles
# Out:
#          danceability    energy   loudness  speechiness  acousticness  \
# cluster
# 0            0.664259  0.466618 -13.364416     0.829938      0.585916
# 1            0.486376  0.311307 -13.203705     0.060157      0.749176
# 2            0.627372  0.693677  -7.606166     0.075051      0.258438
#
#          instrumentalness  liveness   valence       tempo    duration_ms
# cluster
# 0                0.001384  0.435523  0.584054  100.388816   97522.463081
# 1                0.168526  0.182115  0.413258  111.941246  223652.717216
# 2                0.050698  0.199842  0.666450  124.913029  226479.720252

# %%
df.groupby('cluster')[selected_features].mean()
# Out:
#          danceability    energy   loudness  speechiness  acousticness  \
# cluster
# 0            0.664259  0.466618 -13.364416     0.829938      0.585916
# 1            0.486376  0.311307 -13.203705     0.060157      0.749176
# 2            0.627372  0.693677  -7.606166     0.075051      0.258438
#
#          instrumentalness  liveness   valence       tempo    duration_ms
# cluster
# 0                0.001384  0.435523  0.584054  100.388816   97522.463081
# 1                0.168526  0.182115  0.413258  111.941246  223652.717216
# 2                0.050698  0.199842  0.666450  124.913029  226479.720252

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

labels = df['cluster']

sil_score = silhouette_score(X_scaled, labels)
db_score = davies_bouldin_score(X_scaled, labels)
inertia_score = kmeans.inertia_

print("Silhouette Score:", sil_score)
print("Davies-Bouldin Score:", db_score)
print("Inertia:", inertia_score)
# Out:
# Silhouette Score: 0.2423441484973421
# Davies-Bouldin Score: 1.5705032224190083
# Inertia: 658335.0409756744

# %% [markdown]
# BAR **chart**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cluster_profile = df.groupby('cluster')[selected_features].mean()

plt.figure(figsize=(12,6))
sns.barplot(data=cluster_profile.T)
plt.title("Average Feature Values per Cluster")
plt.xlabel("Features")
plt.ylabel("Mean Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Heatmap — Feature Comparison Across **Clusters**

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cluster_profile, annot=True, cmap="coolwarm")
plt.title("Cluster Feature Heatmap")
plt.show()

# %% [markdown]
# # . Distribution Plots — Feature Distribution Per **Cluster**

# %%
for col in ['danceability', 'energy', 'tempo', 'acousticness']:
    plt.figure(figsize=(8,4))
    sns.kdeplot(data=df, x=col, hue='cluster', fill=True)
    plt.title(f"Distribution of {col} by Cluster")
    plt.show()

# %%
df['cluster'] = kmeans.fit_predict(X_scaled)

# %%
df['cluster'] = kmeans.labels_

# %%
df
# Out:
#        popularity_songs  duration_ms  explicit  danceability  energy  key  \
# 0                     0       161427         0         0.563  0.1840    4
# 1                     0       223440         0         0.427  0.1800   10
# 2                     0       208267         0         0.511  0.2060    0
# 3                     0       161933         0         0.676  0.4670    9
# 4                     0       167973         0         0.650  0.2980    9
# ...                 ...          ...       ...           ...     ...  ...
# 95832                70       174800         0         0.674  0.5680    1
# 95833                50       265846         0         0.528  0.6730    4
# 95834                67        82500         0         0.609  0.0172    8
# 95835                66       185250         0         0.562  0.0331    1
# 95836                50       258267         0         0.560  0.5180    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
top_songs = df.sort_values('popularity_songs', ascending=False).groupby('cluster').head(20)
top_songs[['cluster', 'popularity_songs']]
# Out:
#        cluster  popularity_songs
# 35665        2                98
# 35398        2                94
# 35422        2                92
# 35241        2                91
# 35532        2                91
# 35287        2                89
# 35233        1                89
# 35432        2                89
# 35434        2                89
# 35284        2                88
# 35668        2                87
# 35436        1                87
# 35437        2                86
# 35239        2                86
# 32855        2                86
# 35506        2                86
# 35462        2                85
# 35444        2                85
# 35433        2                84
# 35285        2                84
# 35674        2                84
# 32856        2                84
# 34858        1                83
# 35234        1                83
# 35505        1                80
# 34650        1                80
# 34884        1                80
# ...

# %%
cluster_summary = df.groupby('cluster')[selected_features].mean()
cluster_summary
# Out:
#          danceability    energy   loudness  speechiness  acousticness  \
# cluster
# 0            0.664259  0.466618 -13.364416     0.829938      0.585916
# 1            0.486376  0.311307 -13.203705     0.060157      0.749176
# 2            0.627372  0.693677  -7.606166     0.075051      0.258438
#
#          instrumentalness  liveness   valence       tempo    duration_ms
# cluster
# 0                0.001384  0.435523  0.584054  100.388816   97522.463081
# 1                0.168526  0.182115  0.413258  111.941246  223652.717216
# 2                0.050698  0.199842  0.666450  124.913029  226479.720252

# %%
 df.to_csv("final_clustered_songs.csv", index=False)

# %%
df
# Out:
#        popularity_songs  duration_ms  explicit  danceability  energy  key  \
# 0                     0       161427         0         0.563  0.1840    4
# 1                     0       223440         0         0.427  0.1800   10
# 2                     0       208267         0         0.511  0.2060    0
# 3                     0       161933         0         0.676  0.4670    9
# 4                     0       167973         0         0.650  0.2980    9
# ...                 ...          ...       ...           ...     ...  ...
# 95832                70       174800         0         0.674  0.5680    1
# 95833                50       265846         0         0.528  0.6730    4
# 95834                67        82500         0         0.609  0.0172    8
# 95835                66       185250         0         0.562  0.0331    1
# 95836                50       258267         0         0.560  0.5180    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
df = pd.read_csv("final_clustered_songs.csv")

# %%
df
# Out:
#        popularity_songs  duration_ms  explicit  danceability  energy  key  \
# 0                     0       161427         0         0.563  0.1840    4
# 1                     0       223440         0         0.427  0.1800   10
# 2                     0       208267         0         0.511  0.2060    0
# 3                     0       161933         0         0.676  0.4670    9
# 4                     0       167973         0         0.650  0.2980    9
# ...                 ...          ...       ...           ...     ...  ...
# 95832                70       174800         0         0.674  0.5680    1
# 95833                50       265846         0         0.528  0.6730    4
# 95834                67        82500         0         0.609  0.0172    8
# 95835                66       185250         0         0.562  0.0331    1
# 95836                50       258267         0         0.560  0.5180    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...
